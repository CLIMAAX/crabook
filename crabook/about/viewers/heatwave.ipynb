# %% [markdown]
# # Heatwave datasets

# %% [markdown]
# A heatwave is a prolonged period of abnormally hot weather. There are different approaches to define a heatwave. In general, a heatwave is determined using thresholds for air temperature and its persistency (minimum duration as a number of days). The most common definition of a heatwave is the occurrence of multiple consecutive days with the maximum air temperature over a certain threshold. In some methodologies thresholds are also defined for the minimum air temperature.
#
# The source of the heatwave hazard is the EuroHEAT project. The EuroHEAT hazard data are based on the health-related EU-wide definition: For the summer period of June to August, heat waves were defined as days in which the maximum apparent temperature (Tappmax) exceeds the threshold (90th percentile of Tappmax for each month) and the minimum temperature (Tmin) exceeds its threshold (90th percentile of Tmin for each month) for at least two days. The apparent temperature is a measure of relative discomfort due to combined heat and high humidity, developed based on physiological studies on evaporative skin cooling. It can be calculated as a combination of air and dew point temperature.
#
# The EuroHEAT datasets represent (maps below) the average seasonal number of the heatwave days in summer months for selected reference (1986-2010) or projection (2016-2045 and 2046-2075) period. Future climate projections are illustrated for two-time horizons 2016-2045 as a near future, and 2046-2075 as further future. Two representative concentration pathways have been selected: RCP 4.5 (a moderate-emissions scenario in which carbon emissions rise until the 2040s, and then begin to decline) and RCP 8.5 (a high-emissions scenario, in which emissions continue to rise throughout the end of the century). The climate change projected under RCP 8.5 will typically be more severe than under RCP 4.5.
#
# This map shows exposure layers representing Buildings and Built-up density retrieved from Global Human Settlement Layer (GHSL). The map also shows national boundaries (NUTS regions - level 0), but also regions of lower levels up to second level of NUTS regions.
#
#
# :::{tip}
# Use the map layer icon in the top-right corner of the map to select and compare different hazard map layers.
# :::

# %% [markdown]
# ## Historical data

# %%
import folium
import branca

m = folium.Map(
    location=(55, 10),
    zoom_start=4,
    control_scale=True,
)
kajo_geoserver_url = 'https://dev-ichange.kajoservices.com/geoserver/climaax/wms'
geoikp_geoserver_url = 'https://vps.kajoservices.com/geoserver/geoikp/wms'

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:ESM_BUILT_VHR2015CLASS_EUROPE_R2019_3035_10_V1_0_PREP",
        fmt='image/png',
        show=True,
        transparent=True,
        name="Buildings"
    ).add_to(m)

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:GHS_BUILT_LDS2014_GLOBE_R2018A_4326_250_V2_0",
        fmt='image/png',
        show=True,
        transparent=True,
        name="Built-up density"
    ).add_to(m)

folium.WmsTileLayer(
        url=kajo_geoserver_url,
        layers="climaax:heatwave_euroheat_hwnumber_1986_2015",
        fmt='image/png',
        show=True,
        transparent=True,
        name="Heatwave events historical data (1986-2015)"
    ).add_to(m)

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:nuts_level0",
        fmt='image/png',
        show=True,
        transparent=True,
        name="Statistical Regions EU - Level 0"
    ).add_to(m)

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:nuts_level1",
        fmt='image/png',
        show=False,
        transparent=True,
        name="Statistical Regions EU - Level 1"
    ).add_to(m)

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:nuts_level2",
        fmt='image/png',
        show=False,
        transparent=True,
        name="Statistical Regions EU - Level 2"
    ).add_to(m)

colormap = branca.colormap.LinearColormap(
    vmin=1,
    vmax=16,
    colors=["#0571b0", "#4496c4", "#82bcd9", "#b4d6e6", "#e1ecf1", "#f6e5dd", "#f5c0a9", "#ef9377", "#dd494c", "#ca0020"],
    index=[1, 3, 5, 6, 7, 9, 10, 12, 14, 16],
    tick_labels=["1", "3", "5", "6", "7", "9", "10", "12", "14", "16"],
    caption="Number of heatwave events",
)
svg_style = '<style>svg {background-color: white; position: relative; top: 1rem; right: 1rem;}</style>'

m.get_root().header.add_child(folium.Element(svg_style))
colormap.to_step(10).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;style&gt;svg {background-color: white; position: relative; top: 1rem; right: 1rem;}&lt;/style&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a44f2c9f44c600f6e4afe0e0ed445e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a44f2c9f44c600f6e4afe0e0ed445e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a44f2c9f44c600f6e4afe0e0ed445e9 = L.map(
#                 &quot;map_2a44f2c9f44c600f6e4afe0e0ed445e9&quot;,
#                 {
#                     center: [55.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2a44f2c9f44c600f6e4afe0e0ed445e9);
#
#
#
#
#
#             var tile_layer_0a3f3ec655d4860e3cf734ae81d8314a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0a3f3ec655d4860e3cf734ae81d8314a.addTo(map_2a44f2c9f44c600f6e4afe0e0ed445e9);
#
#
#             var macro_element_88d160f927f41654e2f50261537913af = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:ESM_BUILT_VHR2015CLASS_EUROPE_R2019_3035_10_V1_0_PREP&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_88d160f927f41654e2f50261537913af.addTo(map_2a44f2c9f44c600f6e4afe0e0ed445e9);
#
#
#             var macro_element_639aa2d1d6a44a86c0aa5adc167c0979 = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:GHS_BUILT_LDS2014_GLOBE_R2018A_4326_250_V2_0&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_639aa2d1d6a44a86c0aa5adc167c0979.addTo(map_2a44f2c9f44c600f6e4afe0e0ed445e9);
#
#
#             var macro_element_389e8589351fe279ad044163537c65c0 = L.tileLayer.wms(
#                 &quot;https://dev-ichange.kajoservices.com/geoserver/climaax/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;climaax:heatwave_euroheat_hwnumber_1986_2015&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_389e8589351fe279ad044163537c65c0.addTo(map_2a44f2c9f44c600f6e4afe0e0ed445e9);
#
#
#             var macro_element_50dec2f3fff2d066800cd997a31ac942 = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:nuts_level0&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_50dec2f3fff2d066800cd997a31ac942.addTo(map_2a44f2c9f44c600f6e4afe0e0ed445e9);
#
#
#             var macro_element_7642f53c07f3596a77d1991f79e33d5b = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:nuts_level1&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             var macro_element_cf7e8557c342e5d28de79046baa9ea7e = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:nuts_level2&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#     var color_map_11e4705ed598f4b79ce92790427fbac8 = {};
#
#
#     color_map_11e4705ed598f4b79ce92790427fbac8.color = d3.scale.threshold()
#               .domain([1.0, 1.0300601202404809, 1.060120240480962, 1.0901803607214429, 1.1202404809619237, 1.1503006012024048, 1.1803607214428857, 1.2104208416833666, 1.2404809619238477, 1.2705410821643286, 1.3006012024048097, 1.3306613226452906, 1.3607214428857715, 1.3907815631262526, 1.4208416833667334, 1.4509018036072145, 1.4809619238476954, 1.5110220440881763, 1.5410821643286572, 1.5711422845691383, 1.6012024048096194, 1.6312625250501003, 1.6613226452905812, 1.69138276

# %% [markdown]
# ## Future projection (optimistic scenario - RCP 4.5)

# %%
import folium
import branca

m = folium.Map(
    location=(55, 10),
    zoom_start=4,
    control_scale=True,
)
kajo_geoserver_url = 'https://dev-ichange.kajoservices.com/geoserver/climaax/wms'
geoikp_geoserver_url = 'https://vps.kajoservices.com/geoserver/geoikp/wms'

layer_list = [{
    "name": "climaax:heatwave_euroheat_hwnumber_rcp45_2016_2045",
    "title": "Heatwave events 2016-2045 (RCP4.5)"
}, {
    "name": "climaax:heatwave_euroheat_hwnumber_rcp45_2046_2075",
    "title": "Heatwave events 2046-2075 (RCP4.5)"
}]

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:ESM_BUILT_VHR2015CLASS_EUROPE_R2019_3035_10_V1_0_PREP",
        fmt='image/png',
        show=True,
        transparent=True,
        name="Buildings"
    ).add_to(m)

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:GHS_BUILT_LDS2014_GLOBE_R2018A_4326_250_V2_0",
        fmt='image/png',
        show=True,
        transparent=True,
        name="Built-up density"
    ).add_to(m)

is_visible = True
for l in layer_list:
    folium.WmsTileLayer(
        url=kajo_geoserver_url,
        layers=l["name"],
        fmt='image/png',
        show=is_visible,
        transparent=True,
        name=l["title"]
    ).add_to(m)
    is_visible = False

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:nuts_level0",
        fmt='image/png',
        show=True,
        transparent=True,
        name="Statistical Regions EU - Level 0"
    ).add_to(m)

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:nuts_level1",
        fmt='image/png',
        show=False,
        transparent=True,
        name="Statistical Regions EU - Level 1"
    ).add_to(m)

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:nuts_level2",
        fmt='image/png',
        show=False,
        transparent=True,
        name="Statistical Regions EU - Level 2"
    ).add_to(m)

colormap = branca.colormap.LinearColormap(
    vmin=1,
    vmax=16,
    colors=["#0571b0", "#4496c4", "#82bcd9", "#b4d6e6", "#e1ecf1", "#f6e5dd", "#f5c0a9", "#ef9377", "#dd494c", "#ca0020"],
    index=[1, 3, 5, 6, 7, 9, 10, 12, 14, 16],
    tick_labels=["1", "3", "5", "6", "7", "9", "10", "12", "14", "16"],
    caption="Number of heatwave events",
)
svg_style = '<style>svg {background-color: white; position: relative; top: 1rem; right: 1rem;}</style>'

m.get_root().header.add_child(folium.Element(svg_style))
colormap.to_step(10).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;style&gt;svg {background-color: white; position: relative; top: 1rem; right: 1rem;}&lt;/style&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7857ba61cebf00bfc4ef63da98a252a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7857ba61cebf00bfc4ef63da98a252a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7857ba61cebf00bfc4ef63da98a252a = L.map(
#                 &quot;map_e7857ba61cebf00bfc4ef63da98a252a&quot;,
#                 {
#                     center: [55.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e7857ba61cebf00bfc4ef63da98a252a);
#
#
#
#
#
#             var tile_layer_2e9b32825d1a75b6dbfacfe8a7d04c07 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2e9b32825d1a75b6dbfacfe8a7d04c07.addTo(map_e7857ba61cebf00bfc4ef63da98a252a);
#
#
#             var macro_element_d966028d40e783aaa7b065e9e82d1a13 = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:ESM_BUILT_VHR2015CLASS_EUROPE_R2019_3035_10_V1_0_PREP&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_d966028d40e783aaa7b065e9e82d1a13.addTo(map_e7857ba61cebf00bfc4ef63da98a252a);
#
#
#             var macro_element_93fe0f7a678b78a82da1b43681de3c1d = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:GHS_BUILT_LDS2014_GLOBE_R2018A_4326_250_V2_0&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_93fe0f7a678b78a82da1b43681de3c1d.addTo(map_e7857ba61cebf00bfc4ef63da98a252a);
#
#
#             var macro_element_4387feef35c3194b5886666966703f26 = L.tileLayer.wms(
#                 &quot;https://dev-ichange.kajoservices.com/geoserver/climaax/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;climaax:heatwave_euroheat_hwnumber_rcp45_2016_2045&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_4387feef35c3194b5886666966703f26.addTo(map_e7857ba61cebf00bfc4ef63da98a252a);
#
#
#             var macro_element_de4e67128cea589d14e9f4d23b351340 = L.tileLayer.wms(
#                 &quot;https://dev-ichange.kajoservices.com/geoserver/climaax/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;climaax:heatwave_euroheat_hwnumber_rcp45_2046_2075&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             var macro_element_63e210bff86da6595dcedc28575a999f = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:nuts_level0&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_63e210bff86da6595dcedc28575a999f.addTo(map_e7857ba61cebf00bfc4ef63da98a252a);
#
#
#             var macro_element_ba00440b886bc03e27ec48832894a955 = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:nuts_level1&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             var macro_element_2372fec9333266f7557bf3605d607af7 = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:nuts_level2&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#     var color_map_6475ac0090c33b364af950d8aafabfd9 = {};
#
#
#     color_map_6475ac0090c33b364af950d8aafabfd9.color = d3.sc

# %% [markdown]
# ## Future projection (pessimistic scenario - RCP 8.5)

# %%
import folium
import branca

m = folium.Map(
    location=(55, 10),
    zoom_start=4,
    control_scale=True,
)
kajo_geoserver_url = 'https://dev-ichange.kajoservices.com/geoserver/climaax/wms'
geoikp_geoserver_url = 'https://vps.kajoservices.com/geoserver/geoikp/wms'

layer_list = [{
    "name": "climaax:heatwave_euroheat_hwnumber_rcp85_2016_2045",
    "title": "Heatwave events 2016-2045 (RCP8.5)"
}, {
    "name": "climaax:heatwave_euroheat_hwnumber_rcp85_2046_2075",
    "title": "Heatwave events 2046-2075 (RCP8.5)"
}]

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:ESM_BUILT_VHR2015CLASS_EUROPE_R2019_3035_10_V1_0_PREP",
        fmt='image/png',
        show=True,
        transparent=True,
        name="Buildings"
    ).add_to(m)

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:GHS_BUILT_LDS2014_GLOBE_R2018A_4326_250_V2_0",
        fmt='image/png',
        show=True,
        transparent=True,
        name="Built-up density"
    ).add_to(m)

is_visible = True
for l in layer_list:
    folium.WmsTileLayer(
        url=kajo_geoserver_url,
        layers=l["name"],
        fmt='image/png',
        show=is_visible,
        transparent=True,
        name=l["title"]
    ).add_to(m)
    is_visible = False

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:nuts_level0",
        fmt='image/png',
        show=True,
        transparent=True,
        name="Statistical Regions EU - Level 0"
    ).add_to(m)

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:nuts_level1",
        fmt='image/png',
        show=False,
        transparent=True,
        name="Statistical Regions EU - Level 1"
    ).add_to(m)

folium.WmsTileLayer(
        url=geoikp_geoserver_url,
        layers="geoikp:nuts_level2",
        fmt='image/png',
        show=False,
        transparent=True,
        name="Statistical Regions EU - Level 2"
    ).add_to(m)

colormap = branca.colormap.LinearColormap(
    vmin=1,
    vmax=16,
    colors=["#0571b0", "#4496c4", "#82bcd9", "#b4d6e6", "#e1ecf1", "#f6e5dd", "#f5c0a9", "#ef9377", "#dd494c", "#ca0020"],
    index=[1, 3, 5, 6, 7, 9, 10, 12, 14, 16],
    tick_labels=["1", "3", "5", "6", "7", "9", "10", "12", "14", "16"],
    caption="Number of heatwave events",
)
svg_style = '<style>svg {background-color: white; position: relative; top: 1rem; right: 1rem;}</style>'

m.get_root().header.add_child(folium.Element(svg_style))
colormap.to_step(10).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;style&gt;svg {background-color: white; position: relative; top: 1rem; right: 1rem;}&lt;/style&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b2772895cabe4cbac33a60efb2c3d24 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b2772895cabe4cbac33a60efb2c3d24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b2772895cabe4cbac33a60efb2c3d24 = L.map(
#                 &quot;map_8b2772895cabe4cbac33a60efb2c3d24&quot;,
#                 {
#                     center: [55.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8b2772895cabe4cbac33a60efb2c3d24);
#
#
#
#
#
#             var tile_layer_f2f309533dc4944226a4efb7ad906212 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f2f309533dc4944226a4efb7ad906212.addTo(map_8b2772895cabe4cbac33a60efb2c3d24);
#
#
#             var macro_element_396164f707452c9c36f93d62487b5fa0 = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:ESM_BUILT_VHR2015CLASS_EUROPE_R2019_3035_10_V1_0_PREP&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_396164f707452c9c36f93d62487b5fa0.addTo(map_8b2772895cabe4cbac33a60efb2c3d24);
#
#
#             var macro_element_950d2a5df219ece2d1b3304deb791de3 = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:GHS_BUILT_LDS2014_GLOBE_R2018A_4326_250_V2_0&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_950d2a5df219ece2d1b3304deb791de3.addTo(map_8b2772895cabe4cbac33a60efb2c3d24);
#
#
#             var macro_element_8a916909fa5d4e251fa20f0cd325e987 = L.tileLayer.wms(
#                 &quot;https://dev-ichange.kajoservices.com/geoserver/climaax/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;climaax:heatwave_euroheat_hwnumber_rcp85_2016_2045&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_8a916909fa5d4e251fa20f0cd325e987.addTo(map_8b2772895cabe4cbac33a60efb2c3d24);
#
#
#             var macro_element_53f15596b40362623dca6bbe0d795ccb = L.tileLayer.wms(
#                 &quot;https://dev-ichange.kajoservices.com/geoserver/climaax/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;climaax:heatwave_euroheat_hwnumber_rcp85_2046_2075&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             var macro_element_d48b35c8f2f0234d57d7ac913000aa4e = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:nuts_level0&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_d48b35c8f2f0234d57d7ac913000aa4e.addTo(map_8b2772895cabe4cbac33a60efb2c3d24);
#
#
#             var macro_element_d6666102d0a2820ac095fb7088d3c518 = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:nuts_level1&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             var macro_element_f76ee463ce5d6a2604b1dab7f7730d90 = L.tileLayer.wms(
#                 &quot;https://vps.kajoservices.com/geoserver/geoikp/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;geoikp:nuts_level2&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#     var color_map_d3691db11142135f93f9c6c2a2933c19 = {};
#
#
#     color_map_d3691db11142135f93f9c6c2a2933c19.color = d3.sc

# %% [markdown]
# ## References
#
#   - Copernicus Climate Data Store, Heat waves and cold spells in Europe derived from climate projections EuroHEAT (2019): [[source](https://cds.climate.copernicus.eu/cdsapp#!/dataset/sis-heat-and-cold-spells?tab=overview)]
#
#   - Global Human Settlement Layer (GHSL): [[source](https://human-settlement.emergency.copernicus.eu/)]
#   - Teritorial units for statistics (NUTS): [[source](https://ec.europa.eu/eurostat/web/gisco/geodata/statistical-units/territorial-units-statistics)]
